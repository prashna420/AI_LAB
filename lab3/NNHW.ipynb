# %%
import pandas as pd

data = pd.read_csv("circles_binary_classification.csv")

# %% [markdown]
# # Getting the Feel of Data
# - describe
# - info
# - head

# %%
data.describe()
# Out:
#                 X1           X2       label
# count  1000.000000  1000.000000  1000.00000
# mean     -0.000448    -0.000804     0.50000
# std       0.639837     0.641156     0.50025
# min      -1.059502    -1.067768     0.00000
# 25%      -0.619251    -0.612176     0.00000
# 50%       0.008762    -0.003949     0.50000
# 75%       0.621933     0.624822     1.00000
# max       1.033712     1.036004     1.00000

# %%
data.head()
# Out:
#          X1        X2  label
# 0  0.754246  0.231481      1
# 1 -0.756159  0.153259      1
# 2 -0.815392  0.173282      1
# 3 -0.393731  0.692883      1
# 4  0.442208 -0.896723      0

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      1000 non-null   float64
#  1   X2      1000 non-null   float64
#  2   label   1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %% [markdown]
# # Data cleaing
# Here all the 1000 given values are not-null hence **data preparation** is not required

# %% [markdown]
# # General Data Visualization
#
# - Just plotting the data since it is plottable.
# - x1, x2, label(0,1)

# %%
import matplotlib.pyplot as plt
plt.scatter(data['X1'], data['X2'], c=data['label'])

# %%
X = data[["X1", "X2"]].values
Y = data["label"].values

print(X.shape, Y.shape)
# Out:
# (1000, 2) (1000,)

# %%
import torch

X = torch.from_numpy(X).type(torch.float)
Y = torch.from_numpy(Y).type(torch.float)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_32508\4107447795.py:4: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:219.)
#   Y = torch.from_numpy(Y).type(torch.float)

# %%
print(X[:5], Y[:5])
# Out:
# tensor([[ 0.7542,  0.2315],
#         [-0.7562,  0.1533],
#         [-0.8154,  0.1733],
#         [-0.3937,  0.6929],
#         [ 0.4422, -0.8967]]) tensor([1., 1., 1., 1., 0.])

# %%
# Split data into train and test sets
# sklearn.model_selection
# train_test_split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    Y,
                                                    test_size=0.2, # 20% test, 80% train
                                                    random_state=42) # make the random split reproducible

print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 800 200 800 200

# %%
from torch import nn

device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
# Out:
# cpu

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()

        self.layer1 = nn.Linear(in_features=2, out_features=11)
        self.layer2 = nn.Linear(in_features=11, out_features=11)
        self.layer3 = nn.Linear(in_features=11, out_features=11)
        self.layer4 = nn.Linear(in_features=11, out_features=1)
        self.relu = nn.ReLU() # Adding Activation function

    def forward(self, x):
        return self.layer4(self.relu(self.layer3(self.relu(self.layer2(self.relu(self.layer1(x)))))))

ClassificationModel = Model().to(device)

print(ClassificationModel)
# Out:
# Model(
#   (layer1): Linear(in_features=2, out_features=11, bias=True)
#   (layer2): Linear(in_features=11, out_features=11, bias=True)
#   (layer3): Linear(in_features=11, out_features=11, bias=True)
#   (layer4): Linear(in_features=11, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
untrained_pred = ClassificationModel(X_test.to(device))

print(f"Length of predictions: {len(untrained_pred)}, Shape: {untrained_pred.shape}")
print(f"Length of test samples: {len(y_test)}, Shape: {y_test.shape}")
print(f"\nFirst 10 predictions:\n{untrained_pred[:10]}")
print(f"\nFirst 10 test labels:\n{y_test[:10]}")
# Out:
# Length of predictions: 200, Shape: torch.Size([200, 1])
# Length of test samples: 200, Shape: torch.Size([200])
#
# First 10 predictions:
# tensor([[0.1278],
#         [0.1356],
#         [0.0955],
#         [0.1308],
#         [0.0985],
#         [0.1081],
#         [0.1327],
#         [0.1325],
#         [0.0945],
#         [0.1362]], grad_fn=<SliceBackward0>)
#
# First 10 test labels:
# tensor([1., 0., 1., 0., 1., 1., 0., 0., 1., 0.])

# %%
#first 5 prediction
y_pred_labels = torch.round(torch.sigmoid(ClassificationModel(X_test.to(device))[:5]))

print(y_pred_labels)
# Out:
# tensor([[1.],
#         [1.],
#         [1.],
#         [1.],
#         [1.]], grad_fn=<RoundBackward0>)

# %%
#actual value
print(y_test[:5])
# Out:
# tensor([1., 0., 1., 0., 1.])

# %%
# Create a loss function
# loss_fn = nn.BCELoss() # BCELoss = no sigmoid built-in
loss_fn = nn.BCEWithLogitsLoss() # BCEWithLogitsLoss = sigmoid built-in

# Create an optimizer
optimizer = torch.optim.SGD(params=ClassificationModel.parameters(),
                            lr=0.2)

# Calculate accuracy (a classification metric)
def accuracy_fn(y_true, y_pred):
    correct = torch.eq(y_true, y_pred).sum().item() # torch.eq() calculates where two tensors are equal
    acc = (correct / len(y_pred)) * 100
    return acc

# %%
torch.manual_seed(42)

# Set the number of epochs
epochs = 1280

# Put data to target device
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

def train_and_test_loop(
    model: nn.Module,
    epochs: int,
    X_train: torch.Tensor,
    y_train: torch.Tensor,
    X_test: torch.Tensor,
    y_test: torch.Tensor,
    loss_fn: nn.Module,
    optimizer: torch.optim.Optimizer
):
    # lists
    loss_list = []
    acc_list = []
    test_losses = []
    test_acc_list = []



    # Build training and evaluation loop
    for epoch in range(epochs):
        ### Training
        model.train()

        # 1. Forward pass (model outputs raw logits)
        y_logits = model(X_train).squeeze() # squeeze to remove extra `1` dimensions, this won't work unless model and data are on same device
        y_pred = torch.round(torch.sigmoid(y_logits)) # turn logits -> pred probs -> pred labls

        # 2. Calculate loss/accuracy
        # loss = loss_fn(torch.sigmoid(y_logits), # Using nn.BCELoss you need torch.sigmoid()
        #                y_train)
        loss = loss_fn(y_logits, # Using nn.BCEWithLogitsLoss works with raw logits
                    y_train)
        acc = accuracy_fn(y_true=y_train,
                        y_pred=y_pred)

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backwards
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        ### Testing
        model.eval()
        with torch.inference_mode():
            # 1. Forward pass
            test_logits = model(X_test).squeeze()
            test_pred = torch.round(torch.sigmoid(test_logits))
            # 2. Caculate loss/accuracy
            test_loss = loss_fn(test_logits,
                                y_test)
            test_acc = accuracy_fn(y_true=y_test,
                                y_pred=test_pred)


        loss_list.append(loss.item())
        acc_list.append(acc)
        test_losses.append(test_loss.item())
        test_acc_list.append(test_acc)

        # Print out what's happening every 10 epochs
        if epoch % 10 == 0:
            print(f"Epoch: {epoch} | Loss: {loss:.5f}, Accuracy: {acc:.2f}% | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%")

    return loss_list, acc_list, test_losses, test_acc_list

# %%
train_losses, acc_list, test_losses, test_acc = train_and_test_loop(
    model=ClassificationModel,
    epochs=epochs,
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    loss_fn=loss_fn,
    optimizer=optimizer
)
# Out:
# Epoch: 0 | Loss: 0.69376, Accuracy: 50.00% | Test loss: 0.69441, Test acc: 50.00%
# Epoch: 10 | Loss: 0.69222, Accuracy: 50.00% | Test loss: 0.69317, Test acc: 50.00%
# Epoch: 20 | Loss: 0.69158, Accuracy: 64.62% | Test loss: 0.69262, Test acc: 54.50%
# Epoch: 30 | Loss: 0.69114, Accuracy: 54.37% | Test loss: 0.69224, Test acc: 49.00%
# Epoch: 40 | Loss: 0.69081, Accuracy: 54.25% | Test loss: 0.69199, Test acc: 47.50%
# Epoch: 50 | Loss: 0.69051, Accuracy: 53.62% | Test loss: 0.69176, Test acc: 48.00%
# Epoch: 60 | Loss: 0.69020, Accuracy: 54.25% | Test loss: 0.69154, Test acc: 49.00%
# Epoch: 70 | Loss: 0.68989, Accuracy: 55.12% | Test loss: 0.69131, Test acc: 49.50%
# Epoch: 80 | Loss: 0.68953, Accuracy: 57.63% | Test loss: 0.69104, Test acc: 51.50%
# Epoch: 90 | Loss: 0.68911, Accuracy: 59.25% | Test loss: 0.69074, Test acc: 54.00%
# Epoch: 100 | Loss: 0.68868, Accuracy: 60.62% | Test loss: 0.69042, Test acc: 55.50%
# Epoch: 110 | Loss: 0.68818, Accuracy: 61.12% | Test loss: 0.69004, Test acc: 56.50%
# Epoch: 120 | Loss: 0.68749, Accuracy: 61.12% | Test loss: 0.68954, Test acc: 57.00%
# Epoch: 130 | Loss: 0.68692, Accuracy: 61.38% | Test loss: 0.68914, Test acc: 57.50%
# Epoch: 140 | Loss: 0.68630, Accuracy: 61.75% | Test loss: 0.68872, Test acc: 58.50%
# Epoch: 150 | Loss: 0.68561, Accuracy: 62.75% | Test loss: 0.68824, Test acc: 58.00%
# Epoch: 160 | Loss: 0.68483, Accuracy: 63.62% | Test loss: 0.68770, Test acc: 58.50%
# Epoch: 170 | Loss: 0.68394, Accuracy: 64.12% | Test loss: 0.68708, Test acc: 59.50%
# Epoch: 180 | Loss: 0.68292, Accuracy: 65.25% | Test loss: 0.68636, Test acc: 61.00%
# Epoch: 190 | Loss: 0.68175, Accuracy: 66.25% | Test loss: 0.68551, Test acc: 61.50%
# Epoch: 200 | Loss: 0.68041, Accuracy: 67.12% | Test loss: 0.68450, Test acc: 62.50%
# Epoch: 210 | Loss: 0.67868, Accuracy: 69.25% | Test loss: 0.68310, Test acc: 64.50%
# Epoch: 220 | Loss: 0.67678, Accuracy: 69.25% | Test loss: 0.68160, Test acc: 66.50%
# Epoch: 230 | Loss: 0.67461, Accuracy: 70.00% | Test loss: 0.67982, Test acc: 66.50%
# Epoch: 240 | Loss: 0.67209, Accuracy: 70.88% | Test loss: 0.67770, Test acc: 68.00%
# Epoch: 250 | Loss: 0.66909, Accuracy: 71.88% | Test loss: 0.67517, Test acc: 69.00%
# Epoch: 260 | Loss: 0.66554, Accuracy: 72.88% | Test loss: 0.67214, Test acc: 70.00%
# Epoch: 270 | Loss: 0.66124, Accuracy: 75.00% | Test loss: 0.66842, Test acc: 70.50%
# Epoch: 280 | Loss: 0.65593, Accuracy: 79.75% | Test loss: 0.66376, Test acc: 73.00%
# Epoch: 290 | Loss: 0.64931, Accuracy: 82.38% | Test loss: 0.65784, Test acc: 77.00%
# Epoch: 300 | Loss: 0.64103, Accuracy: 84.88% | Test loss: 0.65022, Test acc: 80.50%
# Epoch: 310 | Loss: 0.63045, Accuracy: 87.50% | Test loss: 0.64060, Test acc: 83.00%
# Epoch: 320 | Loss: 0.61670, Accuracy: 91.50% | Test loss: 0.62805, Test acc: 88.00%
# Epoch: 330 | Loss: 0.59866, Accuracy: 94.62% | Test loss: 0.61128, Test acc: 92.00%
# Epoch: 340 | Loss: 0.57461, Accuracy: 96.88% | Test loss: 0.58867, Test acc: 95.00%
# Epoch: 350 | Loss: 0.54257, Accuracy: 98.38% | Test loss: 0.55820, Test acc: 96.00%
# Epoch: 360 | Loss: 0.50626, Accuracy: 97.75% | Test loss: 0.53462, Test acc: 75.00%
# Epoch: 370 | Loss: 0.57985, Accuracy: 59.50% | Test loss: 0.61479, Test acc: 52.00%
# Epoch: 380 | Loss: 0.50917, Accuracy: 70.75% | Test loss: 0.53698, Test acc: 61.50%
# Epoch: 390 | Loss: 0.56698, Accuracy: 58.00% | Test loss: 0.57691, Test acc: 56.50%
# Epoch: 400 | Loss: 0.51797, Accuracy: 64.00% | Test loss: 0.58113, Test acc: 56.50%
# Epoch: 410 | Loss: 0.49134, Accuracy: 68.75% | Test loss: 0.50546, Test acc: 65.50%
# Epoch: 420 | Loss: 0.57045, Accuracy: 57.38% | Test loss: 0.57870, Test acc: 57.00%
# Epoch: 430 | Loss: 0.48238, Accuracy: 68.00% | Test loss: 0.51053, Test acc: 64.50%
# Epoch: 440 | Loss: 0.50484, Accuracy: 62.50% | Test loss: 0.51427, Test acc: 65.00%
# Epoch: 450 | Loss: 0.49573, Accuracy: 63.38% | Test loss: 0.50896, Test acc: 65.00%
# Epoch: 460 | Loss: 0.48130, Accuracy: 66.38% | Test loss: 0.49385, Test acc: 66.00%
# Epoch: 470 | Loss: 0.47309, Accuracy: 68.00% | Test loss: 0.48270, Test acc: 65.50%
# Epoch: 480 | Loss: 0.46498, Accuracy: 69.38% | Test loss: 0.47379, Test acc: 66.50%
# Epoch: 490 | Loss: 0.45495, Accuracy: 71.00% | Test loss: 0.46468, Test acc: 66.50%
# Epoch: 500 | Loss: 0.44168, Accuracy: 73.25% | Test loss: 0.45200, Test acc: 68.00%
# Epoch: 510 | Loss: 0.43668, Accuracy: 73.88% | Test loss: 0.44793, Test acc: 68.50%
# Epoch: 520 | Loss: 0.41604, Accuracy: 76.62% | Test loss: 0.42943, Test acc: 73.00%
# Epoch: 530 | Loss: 0.41280, Accuracy: 76.12% | Test loss: 0.42874, Test acc: 71.00%
# Epoch: 540 | Loss: 0.38873, Accuracy: 79.12% | Test loss: 0.40864, Test acc: 74.50%
# Epoch: 550 | Loss: 0.37682, Accuracy: 80.25% | Test loss: 0.40047, Test acc: 75.00%
# Epoch: 560 | Loss: 0.36987, Accuracy: 80.50% | Test loss: 0.39489, Test acc: 76.00%
# Epoch: 570 | Loss: 0.28496, Accuracy: 87.25% | Test loss: 0.31307, Test acc: 82.50%
# Epoch: 580 | Loss: 0.14146, Accuracy: 97.88% | Test loss: 0.16485, Test acc: 96.00%
# Epoch: 590 | Loss: 0.08258, Accuracy: 99.75% | Test loss: 0.11689, Test acc: 99.50%
# Epoch: 600 | Loss: 0.06811, Accuracy: 99.88% | Test loss: 0.10176, Test acc: 99.50%
# Epoch: 610 | Loss: 0.05764, Accuracy: 99.88% | Test loss: 0.08997, Test acc: 99.50%
# Epoch: 620 | Loss: 0.04974, Accuracy: 99.88% | Test loss: 0.08058, Test acc: 99.50%
# Epoch: 630 | Loss: 0.04360, Accuracy: 99.88% | Test loss: 0.07300, Test acc: 99.50%
# Epoch: 640 | Loss: 0.03866, Accuracy: 99.88% | Test loss: 0.06667, Test acc: 100.00%
# Epoch: 650 | Loss: 0.03443, Accuracy: 100.00% | Test loss: 0.06127, Test acc: 100.00%
# Epoch: 660 | Loss: 0.03086, Accuracy: 100.00% | Test loss: 0.05656, Test acc: 100.00%
# Epoch: 670 | Loss: 0.02792, Accuracy: 100.00% | Test loss: 0.05251, Test acc: 100.00%
# Epoch: 680 | Loss: 0.02544, Accuracy: 100.00% | Test loss: 0.04900, Test acc: 100.00%
# Epoch: 690 | Loss: 0.02333, Accuracy: 100.00% | Test loss: 0.04594, Test acc: 100.00%
# Epoch: 700 | Loss: 0.02152, Accuracy: 100.00% | Test loss: 0.04328, Test acc: 100.00%
# Epoch: 710 | Loss: 0.01995, Accuracy: 100.00% | Test loss: 0.04102, Test acc: 100.00%
# Epoch: 720 | Loss: 0.01856, Accuracy: 100.00% | Test loss: 0.03900, Test acc: 100.00%
# Epoch: 730 | Loss: 0.01734, Accuracy: 100.00% | Test loss: 0.03718, Test acc: 100.00%
# Epoch: 740 | Loss: 0.01625, Accuracy: 100.00% | Test loss: 0.03555, Test acc: 100.00%
# Epoch: 750 | Loss: 0.01528, Accuracy: 100.00% | Test loss: 0.03408, Test acc: 100.00%
# Epoch: 760 | Loss: 0.01442, Accuracy: 100.00% | Test loss: 0.03275, Test acc: 100.00%
# Epoch: 770 | Loss: 0.01364, Accuracy: 100.00% | Test loss: 0.03156, Test acc: 100.00%
# Epoch: 780 | Loss: 0.01294, Accuracy: 100.00% | Test loss: 0.03046, Test acc: 100.00%
# Epoch: 790 | Loss: 0.01230, Accuracy: 100.00% | Test loss: 0.02945, Test acc: 100.00%
# Epoch: 800 | Loss: 0.01171, Accuracy: 100.00% | Test loss: 0.02852, Test acc: 100.00%
# Epoch: 810 | Loss: 0.01118, Accuracy: 100.00% | Test loss: 0.02768, Test acc: 100.00%
# Epoch: 820 | Loss: 0.01068, Accuracy: 100.00% | Test loss: 0.02691, Test acc: 100.00%
# Epoch: 830 | Loss: 0.01023, Accuracy: 100.00% | Test loss: 0.02620, Test acc: 100.00%
# Epoch: 840 | Loss: 0.00980, Accuracy: 100.00% | Test loss: 0.02555, Test acc: 100.00%
# Epoch: 850 | Loss: 0.00940, Accuracy: 100.00% | Test loss: 0.02493, Test acc: 100.00%
# Epoch: 860 | Loss: 0.00904, Accuracy: 100.00% | Test loss: 0.02436, Test acc: 100.00%
# Epoch: 870 | Loss: 0.00870, Accuracy: 100.00% | Test loss: 0.02382, Test acc: 100.00%
# Epoch: 880 | Loss: 0.00838, Accuracy: 100.00% | Test loss: 0.02330, Test acc: 100.00%
# Epoch: 890 | Loss: 0.00808, Accuracy: 100.00% | Test loss: 0.02277, Test acc: 100.00%
# Epoch: 900 | Loss: 0.00781, Accuracy: 100.00% | Test loss: 0.02228, Test acc: 100.00%
# Epoch: 910 | Loss: 0.00755, Accuracy: 100.00% | Test loss: 0.02182, Test acc: 100.00%
# Epoch: 920 | Loss: 0.00730, Accuracy: 100.00% | Test loss: 0.02139, Test acc: 100.00%
# Epoch: 930 | Loss: 0.00707, Accuracy: 100.00% | Test loss: 0.02099, Test acc: 100.00%
# Epoch: 940 | Loss: 0.00685, Accuracy: 100.00% | Test loss: 0.02061, Test acc: 100.00%
# Epoch: 950 | Loss: 0.00665, Accuracy: 100.00% | Test loss: 0.02025, Test acc: 100.00%
# Epoch: 960 | Loss: 0.00645, Accuracy: 100.00% | Test loss: 0.01990, Test acc: 100.00%
# Epoch: 970 | Loss: 0.00627, Accuracy: 100.00% | Test loss: 0.01957, Test acc: 100.00%
# Epoch: 980 | Loss: 0.00609, Accuracy: 100.00% | Test loss: 0.01927, Test acc: 100.00%
# Epoch: 990 | Loss: 0.00593, Accuracy: 100.00% | Test loss: 0.01898, Test acc: 100.00%
# Epoch: 1000 | Loss: 0.00577, Accuracy: 100.00% | Test loss: 0.01869, Test acc: 100.00%
# Epoch: 1010 | Loss: 0.00562, Accuracy: 100.00% | Test loss: 0.01842, Test acc: 100.00%
# Epoch: 1020 | Loss: 0.00547, Accuracy: 100.00% | Test loss: 0.01816, Test acc: 100.00%
# Epoch: 1030 | Loss: 0.00533, Accuracy: 100.00% | Test loss: 0.01794, Test acc: 100.00%
# Epoch: 1040 | Loss: 0.00519, Accuracy: 100.00% | Test loss: 0.01774, Test acc: 100.00%
# Epoch: 1050 | Loss: 0.00503, Accuracy: 100.00% | Test loss: 0.01759, Test acc: 100.00%
# Epoch: 1060 | Loss: 0.00489, Accuracy: 100.00% | Test loss: 0.01737, Test acc: 100.00%
# Epoch: 1070 | Loss: 0.00476, Accuracy: 100.00% | Test loss: 0.01712, Test acc: 100.00%
# Epoch: 1080 | Loss: 0.00464, Accuracy: 100.00% | Test loss: 0.01688, Test acc: 100.00%
# Epoch: 1090 | Loss: 0.00453, Accuracy: 100.00% | Test loss: 0.01664, Test acc: 100.00%
# Epoch: 1100 | Loss: 0.00441, Accuracy: 100.00% | Test loss: 0.01639, Test acc: 100.00%
# Epoch: 1110 | Loss: 0.00431, Accuracy: 100.00% | Test loss: 0.01614, Test acc: 100.00%
# Epoch: 1120 | Loss: 0.00420, Accuracy: 100.00% | Test loss: 0.01593, Test acc: 100.00%
# Epoch: 1130 | Loss: 0.00411, Accuracy: 100.00% | Test loss: 0.01572, Test acc: 100.00%
# Epoch: 1140 | Loss: 0.00401, Accuracy: 100.00% | Test loss: 0.01552, Test acc: 100.00%
# Epoch: 1150 | Loss: 0.00392, Accuracy: 100.00% | Test loss: 0.01533, Test acc: 100.00%
# Epoch: 1160 | Loss: 0.00384, Accuracy: 100.00% | Test loss: 0.01514, Test acc: 100.00%
# Epoch: 1170 | Loss: 0.00376, Accuracy: 100.00% | Test loss: 0.01497, Test acc: 100.00%
# Epoch: 1180 | Loss: 0.00368, Accuracy: 100.00% | Test loss: 0.01480, Test acc: 100.00%
# Epoch: 1190 | Loss: 0.00360, Accuracy: 100.00% | Test loss: 0.01463, Test acc: 100.00%
# Epoch: 1200 | Loss: 0.00353, Accuracy: 100.00% | Test loss: 0.01448, Test acc: 100.00%
# Epoch: 1210 | Loss: 0.00346, Accuracy: 100.00% | Test loss: 0.01432, Test acc: 100.00%
# Epoch: 1220 | Loss: 0.00339, Accuracy: 100.00% | Test loss: 0.01417, Test acc: 100.00%
# Epoch: 1230 | Loss: 0.00333, Accuracy: 100.00% | Test loss: 0.01402, Test acc: 100.00%
# Epoch: 1240 | Loss: 0.00327, Accuracy: 100.00% | Test loss: 0.01389, Test acc: 100.00%
# Epoch: 1250 | Loss: 0.00321, Accuracy: 100.00% | Test loss: 0.01375, Test acc: 100.00%
# Epoch: 1260 | Loss: 0.00316, Accuracy: 100.00% | Test loss: 0.01362, Test acc: 100.00%
# Epoch: 1270 | Loss: 0.00310, Accuracy: 100.00% | Test loss: 0.01350, Test acc: 100.00%

# %% [markdown]
# # Helper function
# Taken from the povided resources.

# %%
import numpy as np

def plot_decision_boundary(model: torch.nn.Module, X: torch.Tensor, y: torch.Tensor):
    """Plots decision boundaries of model predicting on X in comparison to y.

    Source - https://madewithml.com/courses/foundations/neural-networks/ (with modifications)
    """
    # Put everything to CPU (works better with NumPy + Matplotlib)
    model.to("cpu")
    X, y = X.to("cpu"), y.to("cpu")

    # Setup prediction boundaries and grid
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 101), np.linspace(y_min, y_max, 101))

    # Make features
    X_to_pred_on = torch.from_numpy(np.column_stack((xx.ravel(), yy.ravel()))).float()

    # Make predictions
    model.eval()
    with torch.inference_mode():
        y_logits = model(X_to_pred_on)

    # Test for multi-class or binary and adjust logits to prediction labels
    if len(torch.unique(y)) > 2:
        y_pred = torch.softmax(y_logits, dim=1).argmax(dim=1)  # mutli-class
    else:
        y_pred = torch.round(torch.sigmoid(y_logits))  # binary

    # Reshape preds and plot
    y_pred = y_pred.reshape(xx.shape).detach().numpy()
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

# %%
# Plot decision boundaries for training and test sets
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_decision_boundary(ClassificationModel, X_train, y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_decision_boundary(ClassificationModel, X_test, y_test)
